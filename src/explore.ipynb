# %% [markdown]
# # Explore here

# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from dotenv import load_dotenv
import pandas as pd
import matplotlib.pyplot as plt

# load the .env file variables
load_dotenv()
client_id = os.environ.get('CLIENT_ID')
client_secret = os.environ.get('CLIENT_SECRET')

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,client_secret=client_secret,redirect_uri='https://localhost'))

# %%
ID_ARTISTA ='2ziB7fzrXBoh1HUPS6sVFn'
response = sp.artist_top_tracks(ID_ARTISTA)
print(response)
# Out:
# {'tracks': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ziB7fzrXBoh1HUPS6sVFn'}, 'href': 'https://api.spotify.com/v1/artists/2ziB7fzrXBoh1HUPS6sVFn', 'id': '2ziB7fzrXBoh1HUPS6sVFn', 'name': 'Audioslave', 'type': 'artist', 'uri': 'spotify:artist:2ziB7fzrXBoh1HUPS6sVFn'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/78guAsers0klWl6RwzgDLd'}, 'href': 'https://api.spotify.com/v1/albums/78guAsers0klWl6RwzgDLd', 'id': '78guAsers0klWl6RwzgDLd', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273a7292b6863258e889b78d787', 'width': 640, 'height': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e02a7292b6863258e889b78d787', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d00004851a7292b6863258e889b78d787', 'width': 64, 'height': 64}], 'is_playable': True, 'name': 'Audioslave', 'release_date': '2002-11-17', 'release_date_precision': 'day', 'total_tracks': 14, 'type': 'album', 'uri': 'spotify:album:78guAsers0klWl6RwzgDLd'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ziB7fzrXBoh1HUPS6sVFn'}, 'href': 'https://api.spotify.com/v1/artists/2ziB7fzrXBoh1HUPS6sVFn', 'id': '2ziB7fzrXBoh1HUPS6sVFn', 'name': 'Audioslave', 'type': 'artist', 'uri': 'spotify:artist:2ziB7fzrXBoh1HUPS6sVFn'}], 'disc_number': 1, 'duration_ms': 293960, 'explicit': False, 'external_ids': {'isrc': 'USSM10211587'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3YuaBvuZqcwN3CEAyyoaei'}, 'href': 'https://api.spotify.com/v1/tracks/3YuaBvuZqcwN3CEAyyoaei', 'id': '3YuaBvuZqcwN3CEAyyoaei', 'is_local': False, 'is_playable': True, 'name': 'Like a Stone', 'popularity': 79, 'preview_url': 'https://p.scdn.co/mp3-preview/46d898c23fb28b9f52abf78b794aa500988d2132?cid=c6f4a7a28aa040c9ae3d1aea3f46aa54', 'track_number': 5, 'type': 'track', 'uri': 'spotify:track:3YuaBvuZqcwN3CEAyyoaei'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ziB7fzrXBoh1HUPS6sVFn'}, 'href': 'https://api.spotify.com/v1/artists/2ziB7fzrXBoh1HUPS6sVFn', 'id': '2ziB7fzrXBoh1HUPS6sVFn', 'name': 'Audioslave', 'type': 'artist', 'uri': 'spotify:artist:2ziB7fzrXBoh1HUPS6sVFn'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/0HQhToIjonHnJRRPN4jeJU'}, 'href': 'https://api.spotify.com/v1/albums/0HQhToIjonHnJRRPN4jeJU', 'id': '0HQhToIjonHnJRRPN4jeJU', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27307301dd5fedf5ad64cde4882', 'width': 640, 'height': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e0207301dd5fedf5ad64cde4882', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d0000485107301dd5fedf5ad64cde4882', 'width': 64, 'height': 64}], 'is_playable': True, 'name': 'Out of Exile', 'release_date': '2005-01-01', 'release_date_precision': 'day', 'total_tracks': 12, 'type': 'album', 'uri': 'spotify:album:0HQhToIjonHnJRRPN4jeJU'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ziB7fzrXBoh1HUPS6sVFn'}, 'href': 'https://api.spotify.com/v1/artists/2ziB7fzrXBoh1HUPS6sVFn', 'id': '2ziB7fzrXBoh1HUPS6sVFn', 'name': 'Audioslave', 'type': 'artist', 'uri': 'spotify:artist:2ziB7fzrXBoh1HUPS6sVFn'}], 'disc_number': 1, 'duration_ms': 278973, 'explicit': False, 'external_ids': {'isrc': 'USIR10500509'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3zwmW1gM4E8FlHXV5nE16u'}, 'href': 'https://api.spotify.com/v1/tracks/3zwmW1gM4E8FlHXV5nE16u', 'id': '3zwmW1gM4E8FlHXV5nE16u', 'is_local': False, 'is_playable': True, 'name': 'Be Yourself', 'popularity': 70, 'preview_url': None, 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:3zwmW1gM4E8FlHXV5nE16u'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ziB7fzrXBoh1HUPS6sVFn'}, 'href': 'https://api.spotify.com/v1/artists/2ziB7fzrXBoh1HUPS6sVFn', 'id': '2ziB7fzrXBoh1HUPS6sVFn', 'name': 'Audioslave', 'type': 'artist', 'uri': ...

# %%
TRACKS = response['tracks']
df_tracks = pd.DataFrame.from_records(TRACKS)           #Crear DF 
df_tracks
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       293960     False  {'isrc': 'USSM10211587'}
# 1       278973     False  {'isrc': 'USIR10500509'}
# 2       277840     False  {'isrc': 'USSM10211589'}
# 3       222026     False  {'isrc': 'USSM10211584'}
# 4       334906     False  {'isrc': 'USSM10211592'}
# 5       255000     False  {'isrc': 'USIR10500779'}
# 6       279333     False  {'isrc': 'USSM10211593'}
# 7       343400     False  {'isrc': 'USSM10211591'}
# 8       249400     False  {'isrc': 'USSM10211585'}
# 9       260279     False  {'isrc': 'USSM10603156'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/3Y...
# 1  {'spotify': 'https://open.spotify.com/track/3z...
# 2  {'spotify': 'https://open.spotify.com/track/1Q...
# 3  {'spotify': 'https://open.spotify.com/track/1T...
# 4  {'spotify': 'https://open.spotify.com/track/3b...
# 5  {'spotify': 'https://open.spotify.com/track/0o...
# 6  {'spotify': 'https://open.spotify.com/track/33...
# 7  {'spotify': 'https://open.spotify.com/track/2u...
# 8  {'spotify': 'https://open.spotify.com/track/4D...
# 9  {'spotify': 'https://open.spotify.com/track/3z...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/3YuaBvuZqcwN...  3YuaBvuZqcwN3CEAyyoaei
# 1  https://api.spotify.com/v1/tracks/3zwmW1gM4E8F...  3zwmW1gM4E8FlHXV5nE16u
# 2  https://api.spotify.com/v1/tracks/1Qdnvn4XlmZA...  1Qdnvn4XlmZANCVy3XjrQo
# 3  https://api.spotify.com/v1/tracks/1TDk2Jmi4dVZ...  1TDk2Jmi4dVZhm2dum3Jim
# 4  https://api.spotify.com/v1/tracks/3bwAS8cN7Xtz...  3bwAS8cN7Xtzvv5UurJOOX
# 5  https://api.spotify.com/v1/tracks/0o995gJCGeba...  0o995gJCGebaza0LWybToU
# 6  https://api.spotify.com/v1/tracks/33AxY0QUitvt...  33AxY0QUitvte6JV6B6uLE
# 7  https://api.spotify.com/v1/tracks/2uDwRgwGPjXq...  2uDwRgwGPjXq0oj0hNCuFc
# 8  https://api.spotify.com/v1/tracks/4Dz0U7qR4GxI...  4Dz0U7qR4GxIZAOGGEPuTf
# 9  https://api.spotify.com/v1/tracks/3zFG5dyH5rJf...  3zFG5dyH5rJfkZ25fgR173
#
#    is_local  is_playable                 name  popularity  \
# 0     False         True         Like a Stone          79
# 1     False         True          Be Yourself          70
# 2     False         True  Show Me How to Live          69
# 3     False         True              Cochise          65
# 4     False         True     I Am the Highway          65
# 5     False         True    Doesn't Remind Me          61
# 6     False         True             Gasoline          57
# 7     False         True    Shadow on the Sun          56
# 8     False         True         What You Are          54
# 9     False         True       Sound Of A Gun          52
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/46d898c23fb28b9f...             5  track
# 1                                               None             3  track
# 2  https://p.scdn.co/mp3-preview/00fefe058f1622e0...             2  track
# 3  https://p.scdn.co/mp3-preview/7f8318da7b43c860...             1  track
# 4  https://p.scdn.co/mp3-preview/d4e3185b10614eb4...             8  track
# 5                                               None             4  track
# 6  https://p.scdn.co/mp3-preview/b9f5928345c76d91...             3  track
# 7  https://p.scdn.co/mp3-preview/28ff311195097bc1...             7  track
# 8  https://p.scdn.co/mp3-preview/7c166d75049731a0...             4  track
# 9  https://p.scdn.co/mp3-preview/e13c66dce50adee1...             3  track
#
#                                     uri
# 0  spotify:track:3YuaBvuZqcwN3CEAyyoaei
# 1  spotify:track:3zwmW1gM4E8FlHXV5nE16u
# 2  spotify:track:1Qdnvn4XlmZANCVy3XjrQo
# 3  spotify:track:1TDk2Jmi4dVZhm2dum3Jim
# 4  spotify:track:3bwAS8cN7Xtzvv5UurJOOX
# 5  spotify:track:0o995gJCGebaza0LWybToU
# 6  spotify:track:33AxY0QUitvte6JV6B6uLE
# 7  spotify:track:2uDwRgwGPjXq0oj0hNCuFc
# 8  spotify:track:4Dz0U7qR4GxIZAOGGEPuTf
# 9  spotify:track:3zFG5dyH5rJfkZ25fgR173

# %%
df_tracks.sort_values(['popularity'], inplace=True)         #Ordenar DF por popularidad
df_tracks
# Out:
#                                                album  \
# 9  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 9       260279     False  {'isrc': 'USSM10603156'}
# 8       249400     False  {'isrc': 'USSM10211585'}
# 7       343400     False  {'isrc': 'USSM10211591'}
# 6       279333     False  {'isrc': 'USSM10211593'}
# 5       255000     False  {'isrc': 'USIR10500779'}
# 3       222026     False  {'isrc': 'USSM10211584'}
# 4       334906     False  {'isrc': 'USSM10211592'}
# 2       277840     False  {'isrc': 'USSM10211589'}
# 1       278973     False  {'isrc': 'USIR10500509'}
# 0       293960     False  {'isrc': 'USSM10211587'}
#
#                                        external_urls  \
# 9  {'spotify': 'https://open.spotify.com/track/3z...
# 8  {'spotify': 'https://open.spotify.com/track/4D...
# 7  {'spotify': 'https://open.spotify.com/track/2u...
# 6  {'spotify': 'https://open.spotify.com/track/33...
# 5  {'spotify': 'https://open.spotify.com/track/0o...
# 3  {'spotify': 'https://open.spotify.com/track/1T...
# 4  {'spotify': 'https://open.spotify.com/track/3b...
# 2  {'spotify': 'https://open.spotify.com/track/1Q...
# 1  {'spotify': 'https://open.spotify.com/track/3z...
# 0  {'spotify': 'https://open.spotify.com/track/3Y...
#
#                                                 href                      id  \
# 9  https://api.spotify.com/v1/tracks/3zFG5dyH5rJf...  3zFG5dyH5rJfkZ25fgR173
# 8  https://api.spotify.com/v1/tracks/4Dz0U7qR4GxI...  4Dz0U7qR4GxIZAOGGEPuTf
# 7  https://api.spotify.com/v1/tracks/2uDwRgwGPjXq...  2uDwRgwGPjXq0oj0hNCuFc
# 6  https://api.spotify.com/v1/tracks/33AxY0QUitvt...  33AxY0QUitvte6JV6B6uLE
# 5  https://api.spotify.com/v1/tracks/0o995gJCGeba...  0o995gJCGebaza0LWybToU
# 3  https://api.spotify.com/v1/tracks/1TDk2Jmi4dVZ...  1TDk2Jmi4dVZhm2dum3Jim
# 4  https://api.spotify.com/v1/tracks/3bwAS8cN7Xtz...  3bwAS8cN7Xtzvv5UurJOOX
# 2  https://api.spotify.com/v1/tracks/1Qdnvn4XlmZA...  1Qdnvn4XlmZANCVy3XjrQo
# 1  https://api.spotify.com/v1/tracks/3zwmW1gM4E8F...  3zwmW1gM4E8FlHXV5nE16u
# 0  https://api.spotify.com/v1/tracks/3YuaBvuZqcwN...  3YuaBvuZqcwN3CEAyyoaei
#
#    is_local  is_playable                 name  popularity  \
# 9     False         True       Sound Of A Gun          52
# 8     False         True         What You Are          54
# 7     False         True    Shadow on the Sun          56
# 6     False         True             Gasoline          57
# 5     False         True    Doesn't Remind Me          61
# 3     False         True              Cochise          65
# 4     False         True     I Am the Highway          65
# 2     False         True  Show Me How to Live          69
# 1     False         True          Be Yourself          70
# 0     False         True         Like a Stone          79
#
#                                          preview_url  track_number   type  \
# 9  https://p.scdn.co/mp3-preview/e13c66dce50adee1...             3  track
# 8  https://p.scdn.co/mp3-preview/7c166d75049731a0...             4  track
# 7  https://p.scdn.co/mp3-preview/28ff311195097bc1...             7  track
# 6  https://p.scdn.co/mp3-preview/b9f5928345c76d91...             3  track
# 5                                               None             4  track
# 3  https://p.scdn.co/mp3-preview/7f8318da7b43c860...             1  track
# 4  https://p.scdn.co/mp3-preview/d4e3185b10614eb4...             8  track
# 2  https://p.scdn.co/mp3-preview/00fefe058f1622e0...             2  track
# 1                                               None             3  track
# 0  https://p.scdn.co/mp3-preview/46d898c23fb28b9f...             5  track
#
#                                     uri
# 9  spotify:track:3zFG5dyH5rJfkZ25fgR173
# 8  spotify:track:4Dz0U7qR4GxIZAOGGEPuTf
# 7  spotify:track:2uDwRgwGPjXq0oj0hNCuFc
# 6  spotify:track:33AxY0QUitvte6JV6B6uLE
# 5  spotify:track:0o995gJCGebaza0LWybToU
# 3  spotify:track:1TDk2Jmi4dVZhm2dum3Jim
# 4  spotify:track:3bwAS8cN7Xtzvv5UurJOOX
# 2  spotify:track:1Qdnvn4XlmZANCVy3XjrQo
# 1  spotify:track:3zwmW1gM4E8FlHXV5nE16u
# 0  spotify:track:3YuaBvuZqcwN3CEAyyoaei

# %%
df_tracks.head(3)
# Out:
#                                                album  \
# 9  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 9       260279     False  {'isrc': 'USSM10603156'}
# 8       249400     False  {'isrc': 'USSM10211585'}
# 7       343400     False  {'isrc': 'USSM10211591'}
#
#                                        external_urls  \
# 9  {'spotify': 'https://open.spotify.com/track/3z...
# 8  {'spotify': 'https://open.spotify.com/track/4D...
# 7  {'spotify': 'https://open.spotify.com/track/2u...
#
#                                                 href                      id  \
# 9  https://api.spotify.com/v1/tracks/3zFG5dyH5rJf...  3zFG5dyH5rJfkZ25fgR173
# 8  https://api.spotify.com/v1/tracks/4Dz0U7qR4GxI...  4Dz0U7qR4GxIZAOGGEPuTf
# 7  https://api.spotify.com/v1/tracks/2uDwRgwGPjXq...  2uDwRgwGPjXq0oj0hNCuFc
#
#    is_local  is_playable               name  popularity  \
# 9     False         True     Sound Of A Gun          52
# 8     False         True       What You Are          54
# 7     False         True  Shadow on the Sun          56
#
#                                          preview_url  track_number   type  \
# 9  https://p.scdn.co/mp3-preview/e13c66dce50adee1...             3  track
# 8  https://p.scdn.co/mp3-preview/7c166d75049731a0...             4  track
# 7  https://p.scdn.co/mp3-preview/28ff311195097bc1...             7  track
#
#                                     uri
# 9  spotify:track:3zFG5dyH5rJfkZ25fgR173
# 8  spotify:track:4Dz0U7qR4GxIZAOGGEPuTf
# 7  spotify:track:2uDwRgwGPjXq0oj0hNCuFc

# %%
#Analisis entre popularidad y duracion de cada cancion.
plt.scatter(x=df_tracks['popularity'],y=df_tracks['duration_ms'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# CONCLUSION: Sin relacion entre ambas variables

# %%
#Analisis entre popularidad y numero de track dentro del album de cada cancion.
plt.scatter(x=df_tracks['popularity'],y=df_tracks['track_number'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# CONCLUSION: Sin relacion entre ambas variables
